# %%
import time
import numpy as np
import pandas as pd

# %% [markdown]
# # Pandas

# %%
# creando un pandas Series 
arreglo = np.random.randn(10)
serie = pd.Series(arreglo)
print(serie)

# agregando indices a una serie
serie = pd.Series(arreglo, index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
print(serie)

print(serie['f'])
print(serie[['a', 'b', 'c']])
# Out:
# 0   -1.264922
# 1    0.088557
# 2   -0.557965
# 3    1.165541
# 4   -0.693360
# 5   -1.171653
# 6   -0.934193
# 7   -0.657678
# 8   -1.643533
# 9   -0.206657
# dtype: float64
# a   -1.264922
# b    0.088557
# c   -0.557965
# d    1.165541
# e   -0.693360
# f   -1.171653
# g   -0.934193
# h   -0.657678
# i   -1.643533
# j   -0.206657
# dtype: float64
# -1.171653354599133
# a   -1.264922
# b    0.088557
# c   -0.557965
# dtype: float64

# %%
# serie con llave/valor
serie = pd.Series({'dia1': 34, 'dia2': 36, 'dia3': 43, 'dia4': 45, 'dia5': 55})
print(serie)

muestra_serie = serie[['dia1','dia3','dia5']]
print(muestra_serie)
# Out:
# dia1    34
# dia2    36
# dia3    43
# dia4    45
# dia5    55
# dtype: int64
# dia1    34
# dia3    43
# dia5    55
# dtype: int64

# %%
# creando un dataframe
datos = {
    "ventas": [31,89,23,94,87],
    "fecha": ["02/08/2022", "03/08/2022", "04/08/2022", "05/08/2022", "06/08/2022"]
    }

datos_df = pd.DataFrame(datos)

print(datos_df)

# viendo una ubicacion especifica
print(datos_df.loc[0])
print(datos_df.loc[2:4])
print(datos_df.loc[[0,2,4]])


# agregando indices a los datos
datos_df = pd.DataFrame(datos, index=['dia1', 'dia2', 'dia3', 'dia4', 'dia5'])
print(datos_df)

# viendo un elemento especifico
print(datos_df.loc['dia4'])
# Out:
#    ventas       fecha
# 0      31  02/08/2022
# 1      89  03/08/2022
# 2      23  04/08/2022
# 3      94  05/08/2022
# 4      87  06/08/2022
# ventas            31
# fecha     02/08/2022
# Name: 0, dtype: object
#    ventas       fecha
# 2      23  04/08/2022
# 3      94  05/08/2022
# 4      87  06/08/2022
#    ventas       fecha
# 0      31  02/08/2022
# 2      23  04/08/2022
# 4      87  06/08/2022
#       ventas       fecha
# dia1      31  02/08/2022
# dia2      89  03/08/2022
# dia3      23  04/08/2022
# dia4      94  05/08/2022
# dia5      87  06/08/2022
# ventas            94
# fecha     05/08/2022
# Name: dia4, dtype: object

# %%
# cargando archivos csv
datos_df = pd.read_csv('data.csv')
#print(datos_df)

pd.options.display.max_rows=160

datos_df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  117.0     145.0     479.0
# 2        60.0  103.0     135.0     340.0
# 3        45.0  109.0     175.0     282.4
# 4        45.0  117.0     148.0     406.0
# ..        ...    ...       ...       ...
# 164      60.0  105.0       NaN     290.8
# 165      60.0  110.0     145.0     300.0
# 166      60.0  115.0     145.0     310.2
# 167      75.0  120.0     150.0     320.4
# 168      75.0  125.0     150.0     330.4
#
# [169 rows x 4 columns]

# %%
# Cargando json
datos_df = pd.read_json('data.json')
datos_df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# viendo los primeros 10 datos
print(datos_df.head(10))

# viendo los ultimos 10 datos
print(datos_df.tail(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
datos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
datos_df_sin_na = datos_df.dropna()

datos_df_sin_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB

# %%
datos_df_sin_na = datos_df.copy()

print(datos_df_sin_na.info())

datos_df_sin_na.dropna(inplace=True)

print(datos_df_sin_na.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  164 non-null    int64
#  1   Pulse     164 non-null    int64
#  2   Maxpulse  164 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 6.4 KB
# None

# %%
# mostrar nan values en datos_df
print(datos_df.isna().sum())

print(datos_df.info())
# Out:
# Duration    1
# Pulse       2
# Maxpulse    4
# Calories    5
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  168 non-null    float64
#  1   Pulse     167 non-null    float64
#  2   Maxpulse  165 non-null    float64
#  3   Calories  164 non-null    float64
# dtypes: float64(4)
# memory usage: 5.4 KB
# None

# %%
# completando nan values en datos_df
datos_df_con_numeros = datos_df.copy()
datos_df_con_numeros['Pulse'].fillna(0, inplace=True)
print(datos_df_con_numeros.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  168 non-null    float64
#  1   Pulse     169 non-null    float64
#  2   Maxpulse  165 non-null    float64
#  3   Calories  164 non-null    float64
# dtypes: float64(4)
# memory usage: 5.4 KB
# None

# %%
# completando nan values en datos_df con el promedio de los valores
datos_df_con_sin_na = datos_df.copy()
promedio = datos_df_con_sin_na['Calories'].mean()
print(promedio)
datos_df_con_sin_na['Calories'].fillna(promedio, inplace=True)


# completando columna Maxpulse con la moda de los valores
moda = datos_df_con_sin_na['Maxpulse'].mode()[0]
print(moda)
datos_df_con_sin_na['Maxpulse'].fillna(moda, inplace=True)

# completando la columna Pulse con la media de los valores
media = datos_df_con_sin_na['Pulse'].mean()
print(media)
datos_df_con_sin_na['Pulse'].fillna(media, inplace=True)

# completando la columna Duration con la media de los valores
media = datos_df_con_sin_na['Duration'].mean()
print(media)
datos_df_con_sin_na['Duration'].fillna(media, inplace=True)

datos_df_con_sin_na.info()
# Out:
# 375.79024390243904
# 120.0
# 107.41916167664671
# 63.958333333333336
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    float64
#  1   Pulse     169 non-null    float64
#  2   Maxpulse  169 non-null    float64
#  3   Calories  169 non-null    float64
# dtypes: float64(4)
# memory usage: 5.4 KB

# %%
# obteniendo el valor maximo de la columna Duration
maximo = datos_df_con_sin_na['Duration'].max()
print(maximo)

datos_trecientos = datos_df_con_sin_na['Pulse'] == 117

datos_trecientos.sum()
# Out:
# 180.0
# 3

# %%
datos_df_con_sin_na.loc[7, 'Duration'] = 46

for index in datos_df_con_sin_na.index:
    if datos_df_con_sin_na.loc[index, 'Duration'] == 210:
        datos_df_con_sin_na.loc[index, 'Duration'] = 120


# eliminando valores con un valor especifico
for index in datos_df_con_sin_na.index:
    if datos_df_con_sin_na.loc[index, 'Duration'] == 120:
        datos_df_con_sin_na.drop(index,inplace=True)


datos_df_con_sin_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  162 non-null    float64
#  1   Pulse     162 non-null    float64
#  2   Maxpulse  162 non-null    float64
#  3   Calories  162 non-null    float64
# dtypes: float64(4)
# memory usage: 10.4 KB

# %%
# viendo los duplicados
print(datos_df_con_sin_na['Pulse'].duplicated)


# eliminando duplicados
datos_df_con_sin_na['Pulse'].drop_duplicates(inplace=True)
print(datos_df_con_sin_na)

# viendo informacion de datos_df_con_sin_na
print(datos_df_con_sin_na.info())
# Out:
# <bound method Series.duplicated of 0      110.000000
# 1      117.000000
# 2      103.000000
# 3      109.000000
# 4      117.000000
# 5      102.000000
# 6      110.000000
# 7      104.000000
# 8      109.000000
# 9       98.000000
# 10     103.000000
# 11     100.000000
# 12     107.419162
# 13     104.000000
# 14      98.000000
# 15      98.000000
# 16     100.000000
# 17      90.000000
# 18     103.000000
# 19      97.000000
# 20     108.000000
# 21     100.000000
# 22     130.000000
# 23     105.000000
# 24     102.000000
# 25     100.000000
# 26      92.000000
# 27     103.000000
# 28     100.000000
# 29     102.000000
# 30      92.000000
# 31      90.000000
# 32     101.000000
# 33      93.000000
# 34     107.000000
# 35     114.000000
# 39     104.000000
# 41      98.000000
# 42     100.000000
# 43     111.000000
# 44     111.000000
# 45      99.000000
# 46     109.000000
# 47     111.000000
# 48     108.000000
# 49     111.000000
# 50     107.000000
# 51     123.000000
# ...

# %%
print(datos_df_con_sin_na.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  155 non-null    float64
#  1   Pulse     155 non-null    float64
#  2   Maxpulse  155 non-null    float64
#  3   Calories  155 non-null    float64
# dtypes: float64(4)
# memory usage: 6.1 KB
# None

# %%
merge1_df = pd.read_csv("merge1.csv") 
merge2_df = pd.read_csv("merge2.csv")

full_merge = pd.concat([merge1_df , merge2_df ])

full_merge = pd.concat([full_merge,merge1_df])

print(full_merge)
# Out:
#      Id  Q1  Q2  Q3  Q4
# 0     1   1  -1   1   8
# 1     2   3  -1   1   4
# 2     3  10   3   2   6
# 3     4   9  -1  10  10
# 4     5  10   2   6   1
# 5     6   1  -1   1   1
# 6     7   1  -1   1   8
# 7     8   1  -1   1   1
# 8     9   9  -1  10  10
# 9    10   2  -1   1   1
# 0  1277  10  10   4   6
# 1  1278   2  -1   5   4
# 2  1279   2  -1   4   5
# 3  1280   1  -1   2   3
# 4  1281  10   2   3   4
# 5  1282   2  -1   3   6
# 6  1283  10  10   2  10
# 7  1284   9  -1   8   9
# 8  1285  11  11   1   2
# 9  1286  10   6   6   6
# 0     1   1  -1   1   8
# 1     2   3  -1   1   4
# 2     3  10   3   2   6
# 3     4   9  -1  10  10
# 4     5  10   2   6   1
# 5     6   1  -1   1   1
# 6     7   1  -1   1   8
# 7     8   1  -1   1   1
# 8     9   9  -1  10  10
# 9    10   2  -1   1   1

# %%
merge3_df = pd.read_csv("merge3.csv") 
merge4_df = pd.read_csv("merge4.csv")


# datos_mergeados = dataframe.merge(rigth, opcionales)
todo_merge = merge3_df.merge(merge3_df, how='inner', on='persona') 

print(todo_merge)
# Out:
#    persona  maritl_x  numhhd_x  maritl_y  numhhd_y
# 0        1         6         3         6         3
# 1        2         4         3         4         3
# 2        3         6         2         6         2
# 3        4         4         1         4         1
# 4        5         4         1         4         1
# 5        6         2         2         2         2
# 6        7         2         2         2         2
# 7        8         2         2         2         2
# 8        9         6         2         6         2
# 9       10         6         1         6         1
